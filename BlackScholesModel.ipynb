# %% [markdown]
# ## Option Pricing Using the Black-Scholes MOdel
#
# In finance, this model is one of the most widely used methods for pricing options and calculates the theoretical value of an option based on five key variables of:
#
#
# *   Underlying Price (S)
# *   Strike Price (K)
# *   Time to Expiration (T)
# *   Volatility (Sigma)
# *   RIsk Free Rate (R)

# %% [markdown]
# Import Necessary Libraries

# %%
import math
from scipy.stats import norm

# %% [markdown]
# ## Define the Variables
#
# I'll just use examples that were in John Hull's Derivatives book - its kind of famous for this stuff.

# %%
S = 42 # Underlying Price
K = 40 # Strike Price
T = 0.5 # Time to Expiration
r = 0.1 # Risk-Free Rate
vol = 0.2 # Volatility (sigma)

# %% [markdown]
# ## Calculate d1
#
# The formula for d1 in the Black-Scholes-Merton model is:

# %% [markdown]
# ![Screenshot 2025-01-06 014204.png](data:image/png;base64,...)

# %%
d1 = (math.log(S/K) + (r + 0.5 * vol **2)*T) / (vol * math.sqrt(T))

# %% [markdown]
# ## Calculate d2
#
# The formula for d2 is simply:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
d2 = d1 - (vol * math.sqrt(T))

# %% [markdown]
# ## Calculate Call Option Price
#
# The call option price (C) in the Black-Scholes-Merton model is calculated using the formula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
C = S * norm.cdf(d1) - K * math.exp(-r * T) * norm.cdf(d2)

# %% [markdown]
# ## Calculate Put Option Price
#
# Finally, the put option price (P) is calculated as:
#
# ![image.png](data:image/png;base64,...)

# %%
P = K * math.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

# %% [markdown]
# ## Print the Results

# %%
print("The value of d1 is: ", round(d1, 4))
print("The value of d2 is: ", round(d2, 4))
print("The price of the call option is: $", round(C, 2))
print("The price of the put option is: $", round(P, 2))
# Out:
# The value of d1 is:  0.7693
# The value of d2 is:  0.6278
# The price of the call option is: $ 4.76
# The price of the put option is: $ 0.81
